# %% [markdown]
# # White House News Scraper
#
# This notebook scrapes news articles from [whitehouse.gov/news](https://www.whitehouse.gov/news/).
#
# **Features:**
# - Uses `white_house_functions.py` for core logic.
# - Saves articles as JSON in `01_Outputs` (including categories).
# - Skips already collected articles using `article_tracking.csv`.
# - Supports scraping multiple pages.

# %%
from white_house_functions import scrape_news_pages

## CONFIGURATION
START_PAGE = 46
END_PAGE = 159  # Set this to the number of pages you want to scrape

# %% [markdown]
# ## Run Scraper
#
# Execute the scraper for the specified page range.

# %%
print(f"Starting scrape from page {START_PAGE} to {END_PAGE}...")
new_articles, skipped = scrape_news_pages(START_PAGE, END_PAGE)

print("\n" + "="*30)
print("SCRAPE COMPLETED")
print(f"- New articles collected: {len(new_articles)}")
print(f"- Articles skipped (duplicates): {skipped}")
print("="*30)
# Out:
# Starting scrape from page 46 to 159...
#
# --- Scraping Page 46: https://www.whitehouse.gov/news/page/46/ ---
# Found 10 articles candidate.
#   - Fetching [Articles]: President Trump Isn’t Backing Down from Crushing Radical Left Violence
#   * Rate limited fetching content on https://www.whitehouse.gov/articles/2025/09/president-trump-isnt-backing-down-from-crushing-radical-left-violence/. Retrying in 11.1 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 print(f"Starting scrape from page {START_PAGE} to {END_PAGE}...")
# ----> 2 new_articles, skipped = scrape_news_pages(START_PAGE, END_PAGE)
#       4 print("\n" + "="*30)
#       5 print("SCRAPE COMPLETED")
#
# File c:\Users\peter\Desktop\vscode\main\white_house\white_house_functions.py:216, in scrape_news_pages(start_page, end_page)
#     213     continue
#     215 print(f"  - Fetching [{article['category']}]: {title}")
# --> 216 content = get_article_content(article['link'])
#     217 article['content'] = content
#     219 save_article(article)
#
# File c:\Users\peter\Desktop\vscode\main\white_house\white_house_functions.py:153, in get_article_content(url)
#     151     wait_time = random.uniform(10.0, 20.0) * (attempt + 1)
#     152     print(f"  * Rate limited fetching content on {url}. Retrying in {wait_time:.1f} seconds...")
# --> 153     time.sleep(wait_time)
#     154 else:
#     155     return ""
#
# KeyboardInterrupt:
