# %% [markdown]
# # White House News Scraper
#
# This notebook scrapes news articles from [whitehouse.gov/news](https://www.whitehouse.gov/news/).
#
# **Features:**
# - Uses `white_house_functions.py` for core logic.
# - Saves articles as JSON in `01_Outputs` (including categories).
# - Skips already collected articles using `article_tracking.csv`.
# - Supports scraping multiple pages.

# %%
from white_house_functions import scrape_news_pages

## CONFIGURATION
START_PAGE = 68
END_PAGE = 160  # Set this to the number of pages you want to scrape

START_PAGE = 1
END_PAGE = 4

# %% [markdown]
# ## Run Scraper
#
# Execute the scraper for the specified page range.

# %%
print(f"Starting scrape from page {START_PAGE} to {END_PAGE}...")
new_articles, skipped = scrape_news_pages(START_PAGE, END_PAGE)

print("\n" + "="*30)
print("SCRAPE COMPLETED")
print(f"- New articles collected: {len(new_articles)}")
print(f"- Articles skipped (duplicates): {skipped}")
print("="*30)
# Out:
# Starting scrape from page 1 to 4...
#
# --- Scraping Page 1: https://www.whitehouse.gov/news/ ---
# Found 10 articles candidate.
#   - Fetching [Releases]: The Secure America Act Ends Democrat Obstruction— Fully Funds CBP, ICE and President Trump’s Border Security Agenda
#   - Fetching [Briefings & Statements]: Congressional Bills H.R. 3490 and S. 2393 Signed into Law
#   - Fetching [Briefings & Statements]: First Lady Melania Trump Honors America’s Next Generation of Top AI Talent at Historic Presidential AI Challenge Awards Ceremony
#   - Fetching [Presidential Actions]: Nomination Sent to the Senate
#   - Fetching [Briefings & Statements]: America 250: Presidential Message on the Anniversary of D-Day
#   - Fetching [Briefings & Statements]: Presidential Message on National Ocean Month
#   - Fetching [Fact Sheets]: Fact Sheet: President Donald J. Trump Signs Historic Directive on AI in the National Security Enterprise
# ...
