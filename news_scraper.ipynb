# %% [markdown]
# # White House News Scraper
#
# This notebook scrapes news articles from [whitehouse.gov/news](https://www.whitehouse.gov/news/).
#
# **Features:**
# - Uses `white_house_functions.py` for core logic.
# - Saves articles as JSON in `01_Outputs` (including categories).
# - Skips already collected articles using `article_tracking.csv`.
# - Supports scraping multiple pages.

# %%
from white_house_functions import scrape_news_pages

## CONFIGURATION
START_PAGE = 68
END_PAGE = 160  # Set this to the number of pages you want to scrape

START_PAGE = 1
END_PAGE = 3

# %% [markdown]
# ## Run Scraper
#
# Execute the scraper for the specified page range.

# %%
print(f"Starting scrape from page {START_PAGE} to {END_PAGE}...")
new_articles, skipped = scrape_news_pages(START_PAGE, END_PAGE)

print("\n" + "="*30)
print("SCRAPE COMPLETED")
print(f"- New articles collected: {len(new_articles)}")
print(f"- Articles skipped (duplicates): {skipped}")
print("="*30)
# Out:
# Starting scrape from page 1 to 3...
#
# --- Scraping Page 1: https://www.whitehouse.gov/news/ ---
# Found 10 articles candidate.
#   - Fetching [Presidential Actions]: Commitment to Countering Cartel Criminal Activity
#   - Fetching [Presidential Actions]: Combating Cybercrime, Fraud, and Predatory Schemes Against American Citizens
#   * Rate limited fetching content on https://www.whitehouse.gov/presidential-actions/2026/03/combating-cybercrime-fraud-and-predatory-schemes-against-american-citizens/. Retrying in 14.8 seconds...
#   - Fetching [Articles]: White House Unveils President Trump’s Cyber Strategy for America
#   - Fetching [Fact Sheets]: Fact Sheet: President Donald J. Trump Combats Cybercrime, Fraud, and Predatory Schemes Against American Citizens
#   - Fetching [Articles]: America’s Unstoppable Momentum in Operation Epic Fury
#   - Fetching [Briefings & Statements]: America 250: Presidential Message on the Anniversary of the Boston Massacre
#   - Fetching [Articles]: President Trump Secures Historic Commitment to Keep Electricity Costs Down Amid Data Center Boom
#   - Fetching [Fact Sheets]: Fact Sheet: President Donald J. Trump Advances Energy Affordability with the Ratepayer Protection Pledge
#   * Rate limited fetching content on https://www.whitehouse.gov/fact-sheets/2026/03/fact-sheet-president-donald-j-trump-advances-energy-affordability-with-the-ratepayer-protection-pledge/. Retrying in 17.5 seconds...
#   - Fetching [Articles]: Ratepayer Protection Pledge
#   * Rate limited fetching content on https://www.whitehouse.gov/articles/2026/03/ratepayer-protection-pledge/. Retrying in 12.5 seconds...
#   - Fetching [Presidential Actions]: Ratepayer Protection Pledge Proclamation
#
# --- Scraping Page 2: https://www.whitehouse.gov/news/page/2/ ---
# Found 10 articles candidate.
#   - Fetching [Articles]: America’s Warriors Are Obliterating Iranian Terror Regime with Unrelenting Force
#   - Fetching [Briefings & Statements]: Presidential Message on Holi
#   * Rate limited fetching content on https://www.whitehouse.gov/briefings-statements/2026/03/presidential-message-on-holi/. Retrying in 17.8 seconds...
#   - Fetching [Presidential Actions]: Nominations Sent to the Senate
#   - Fetching [Articles]: ICYMI: Update from CENTCOM Commander on Operation Epic Fury
#   - Fetching [Briefings & Statements]: America 250: Presidential Message on the Birthday of Alexander Graham Bell
#   - Fetching [Briefings & Statements]: Presidential Message on Women’s History Month
#   - Fetching [Articles]: Operation Epic Fury: Unmatched Power, Unrelenting Force of America’s Warriors
#   * Rate limited fetching content on https://www.whitehouse.gov/articles/2026/03/operation-epic-fury-unmatched-power-unrelenting-force-of-americas-warriors/. Retrying in 12.9 seconds...
#   - Fetching [Articles]: Another New Poll Shows Massive Support for SAVE America Act
#   - Fetching [Articles]: 74 Times President Trump Has Made Clear That Iran Cannot Have a Nuclear Weapon
#   - Fetching [Briefings & Statements]: Presidential Message on Colorectal Cancer Awareness Month
#
# --- Scraping Page 3: https://www.whitehouse.gov/news/page/3/ ---
# Found 10 articles candidate.
#   - Fetching [Briefings & Statements]: First Lady Melania Trump Addresses U.N. Security Council, Championing Peace Through Education
#   - Fetching [Presidential Actions]: Nominations Sent to the Senate
#   - Fetching [Articles]: The Iranian Regime’s Decades of Terrorism Against American Citizens
#   - Fetching [Briefings & Statements]: The President and First Lady’s Message on Read Across America Day
#   - Fetching [Briefings & Statements]: 65th Anniversary of the Peace Corps
#   - Fetching [Articles]: Peace Through Strength: President Trump Launches Operation Epic Fury to Crush Iranian Regime, End Nuclear Threat
#   - Fetching [Articles]: President Trump Is Delivering for Texans
#   - Fetching [Articles]: President Trump Delivers his 2026 State of the Union Address
#   * Rate limited fetching content on https://www.whitehouse.gov/articles/2026/02/president-trump-delivers-his-2026-state-of-the-union-address/. Retrying in 17.7 seconds...
#   - Skipping duplicate: WHAT THEY ARE SAYING: President Trump Heralds America’s Golden Age in Historic State of the Union Address (February 25, 2026)
#   - Skipping duplicate: Democrats Showed Whose Side They’re On — And it’s Not the American People (February 25, 2026)
#
# ==============================
# SCRAPE COMPLETED
# - New articles collected: 28
# - Articles skipped (duplicates): 2
# ==============================
