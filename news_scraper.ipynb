# %% [markdown]
# # White House News Scraper
#
# This notebook scrapes news articles from [whitehouse.gov/news](https://www.whitehouse.gov/news/).
#
# **Features:**
# - Uses `white_house_functions.py` for core logic.
# - Saves articles as JSON in `01_Outputs` (including categories).
# - Skips already collected articles using `article_tracking.csv`.
# - Supports scraping multiple pages.

# %%
from white_house_functions import scrape_news_pages

## CONFIGURATION
START_PAGE = 34
END_PAGE = 49  # Set this to the number of pages you want to scrape

# %% [markdown]
# ## Run Scraper
#
# Execute the scraper for the specified page range.

# %%
print(f"Starting scrape from page {START_PAGE} to {END_PAGE}...")
new_articles, skipped = scrape_news_pages(START_PAGE, END_PAGE)

print("\n" + "="*30)
print("SCRAPE COMPLETED")
print(f"- New articles collected: {len(new_articles)}")
print(f"- Articles skipped (duplicates): {skipped}")
print("="*30)
# Out:
# Starting scrape from page 30 to 49...
#
# --- Scraping Page 30: https://www.whitehouse.gov/news/page/30/ ---
# Found 10 articles candidate.
#   - Fetching [Fact Sheets]: Fact Sheet: The United States, Switzerland, and Liechtenstein Reach a Historic Trade Deal
#   - Fetching [Briefings & Statements]: Joint Statement on a Framework for a United States – Switzerland – Liechtenstein Agreement on Fair, Balanced, and Reciprocal Trade
#   - Fetching [Articles]: We’re Making Big Progress on Prices — and We’ll Keep Working to Make Sure Everyone Benefits
#   - Fetching [Fact Sheets]: Fact Sheet: President Donald J. Trump Announces Historic Trade Deals with Western Hemisphere Trading Partners
#   - Fetching [Fact Sheets]: Joint Fact Sheet on President Donald J. Trump’s Meeting with President Lee Jae Myung
#   - Fetching [Briefings & Statements]: Joint Statement on Framework for United States-El Salvador Agreement on Reciprocal Trade
#   - Fetching [Briefings & Statements]: Joint Statement on Framework for United States-Ecuador Agreement on Reciprocal Trade
#   - Fetching [Briefings & Statements]: Joint Statement on Framework for United States-Guatemala Agreement on Reciprocal Trade
#   - Fetching [Briefings & Statements]: Joint Statement on Framework for a United States-Argentina Agreement on Reciprocal Trade and Investment
#   - Fetching [Fact Sheets]: Fact Sheet: President Donald J. Trump Fosters the Future for American Children and Families
#
# --- Scraping Page 31: https://www.whitehouse.gov/news/page/31/ ---
# Found 10 articles candidate.
#   - Fetching [Presidential Actions]: Fostering the Future for American Children and Families
#   - Fetching [Briefings & Statements]: First Lady Melania Trump Announces Executive Order on Fostering the Future, Opens New Opportunities for Public-Private Partnerships
#   - Fetching [Briefings & Statements]: Congressional Bill H.R. 5371 Signed into Law
#   - Fetching [Briefings & Statements]: Presidential Message on Victory Day for World War I
#   - Fetching [Presidential Actions]: Veterans Day, 2025
#   - Fetching [Presidential Actions]: 250th Anniversary of the Founding of the United States Marine Corps
#   - Fetching [Articles]: NEW DATA: Lower Prices, Bigger Paychecks
#   - Fetching [Articles]: Trump Administration Cracks Down on Foreign-Owned Meat Packing Cartels
#   - Fetching [Presidential Actions]: Anti-Communism Week, 2025
#   - Fetching [Fact Sheets]: Fact Sheet: President Donald J. Trump Secures Major Settlement with Cornell University
#
# --- Scraping Page 32: https://www.whitehouse.gov/news/page/32/ ---
# Found 10 articles candidate.
#   - Fetching [Articles]: Democrats Are to Blame for Airport Chaos
#   - Fetching [Briefings & Statements]: First Lady Melania Trump Named “Patriot of the Year”
#   - Fetching [Presidential Actions]: Nomination Sent to the Senate
#   - Fetching [Fact Sheets]: Fact Sheet: President Donald J. Trump Announces Major Developments in Bringing Most-Favored-Nation Pricing to American Patients
#   - Fetching [Articles]: Americans Are Paying Less This Thanksgiving 🦃
#   - Skipping duplicate: Nominations Sent to the Senate
#   - Fetching [Briefings & Statements]: Presidential Message on National Lung Cancer Awareness Month
#   - Fetching [Articles]: ✅ Promises Made, Promises Kept — One Year Later
#   - Fetching [Presidential Actions]: Modifying Reciprocal Tariff Rates Consistent with the Economic and Trade Arrangement Between the United States and the People’s Republic of China
#   - Fetching [Presidential Actions]: Modifying Duties Addressing the Synthetic Opioid Supply Chain in the People’s Republic of China
#
# --- Scraping Page 33: https://www.whitehouse.gov/news/page/33/ ---
# Found 10 articles candidate.
#   - Fetching [Briefings & Statements]: Presidential Message on National Alzheimer’s Disease Awareness Month
#   - Fetching [Briefings & Statements]: Presidential Message on National Native American Heritage Month
#   - Fetching [Briefings & Statements]: Presidential Message on National Entrepreneurship Month
#   - Fetching [Briefings & Statements]: Presidential Message on Critical Infrastructure Security and Resilience Month
#   - Fetching [Briefings & Statements]: Presidential Message on National Diabetes Month
#   - Fetching [Articles]: Thank a Democrat for Five-Hour TSA Lines, Mass Flight Delays
#   - Fetching [Articles]: President Trump on 60 Minutes: “Greatest Nine Months in the History of the Presidency”
#   - Fetching [Fact Sheets]: Fact Sheet: President Donald J. Trump Strikes Deal on Economic and Trade Relations with China
#   - Fetching [Briefings & Statements]: Presidential Message on All Saints’ Day
#   - Fetching [Briefings & Statements]: White House Public Tours to Reopen in December 2025
#
# --- Scraping Page 34: https://www.whitehouse.gov/news/page/34/ ---
# Failed to fetch https://www.whitehouse.gov/news/page/34/: 403
# No articles found on page 34. Stopping.
#
# ==============================
# SCRAPE COMPLETED
# - New articles collected: 39
# - Articles skipped (duplicates): 1
# ==============================
